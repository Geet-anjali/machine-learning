# %% [markdown]
# # Import Libraries

# %%
#import libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import re
import requests as rq
from bs4 import BeautifulSoup
import random
import nltk
#from wordcloud import WordCloud
import os
import spacy
#nlp = spacy.load('en_core_web_sm')
#from textblob import TextBlob
from nltk.stem.wordnet import WordNetLemmatizer

#from pattern.en import sentiment
# Out:
# C:\Users\gargi\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Read Input File Having URLS Of Article

# %%
#read input.csv file 
data_url = pd.read_csv("Input.csv")
df = pd.DataFrame(data_url)
df
# Out:
#      URL_ID                                                URL
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 2 columns]

# %%
Postive_Score =[]
Negative_Score=[]
Polarity_Score=[]
Subjectivity_Score =[]
AVG_SENTENCE_LENGTH=[]
PERCENTAGE_COMPLEX_WORDS=[]
FOG_INDEX=[]
AVG_NUMBER_OF_WORDS_PER_SENTENCE=[]
COMPLEX_WORD_COUNT=[]
WORD_COUNT=[]
SYLLABLE_PER_WORD=[]
PERSONAL_PRONOUNS=[]
AVG_WORD_LENGTH=[]

# %%
# extrating article from each URL and saving in a text file with a name as its URL_ID 
for i in df.index:
    url  =df['URL'][i]
    url_Id =df['URL_ID'][i]
    reqs = rq.get(url,headers={"User-Agent": "XY"})
    soup = BeautifulSoup(reqs.text, 'html.parser')
    Article_title = soup.title.string
    Article_text = soup.find(class_="td-post-content")
    #print(Article_title)
    #print(Article_text.get_text())
    
    # open a text new file nad name it with urlID
    f = open("textFiles/{}".format(url_Id),'w')
    
    # write on text file
    f.write(Article_title)
    f.write(Article_text.get_text())
    
    #remove number link and text
    text_nonum= rem_num_text_link(text_nonum)
    
    #remove StopWords of all type

# %%
# Out:
# 6429

# %% [markdown]
# # Remove Number Link Puctuation

# %%
rem_num_text_link(text_nonum): 
    #Converting text to word separation or csv format
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(Article_text.get_text())

    text_nonum = re.sub(r'\d+', '',Article_text.get_text())

    # To remove link from text
    text_nonum=re.sub(r'http\S+', '', text_nonum)


    #remove punctuation from text
    text_nonum =re.sub(r'[^\w\s]', '',  text_nonum)

    #Remove number From text
    text_nonum= re.sub(" \d+", " ",text_nonum)

    #remove multiple space
    text_nonum =re.sub(' +', ' ', text_nonum)
    print(text_nonum)
    
    return text_nonum
# Out:
# Big Data
# ...

# %% [markdown]
# # StopWords

# %%
    def StopWord(text_nonum, Stopwords):
        tokens =text_nonum.split(" ")
        tokens_filtered= [word for word in tokens if not word.lower() in Stopwords]
        return (" ").join(tokens_filtered)

# %%
    # filtering Auditor Stop words from the text
    with open("stopWords/StopWords_Auditor.txt") as f:
        StopWords_Auditor = f.read().splitlines()
        print(StopWords_Auditor)
    StopWords_Auditor=[x.lower() for x in StopWords_Auditor]
    print(StopWords_Auditor)
    text = StopWord(text_nonum,StopWords_Auditor)
# Out:
# ['ERNST', 'YOUNG', 'DELOITTE', 'TOUCHE', 'KPMG', 'PRICEWATERHOUSECOOPERS', 'PRICEWATERHOUSE', 'COOPERS']
# ['ernst', 'young', 'deloitte', 'touche', 'kpmg', 'pricewaterhousecoopers', 'pricewaterhouse', 'coopers']

# %%
    # filtering Currencies Stop words from the text
    with open("stopWords/StopWords_Currencies.txt") as f:
        StopWords_Currencies = f.read().splitlines()
        print(StopWords_Currencies)

    StopWords_Currencies=[x.lower() for x in StopWords_Currencies]
    print(StopWords_Currencies)

    text = StopWord(text,StopWords_Currencies)
# Out:
# ['AFGHANI  | Afghanistan ', 'ARIARY | Madagascar ', 'BAHT | Thailand ', 'BALBOA | Panama ', 'BIRR | Ethiopia ', 'BOLIVAR | Venezuela ', 'BOLIVIANO  | Bolivia ', 'CEDI | Ghana ', 'COLON  | Costa Rica ', 'CÓRDOBA  | Nicaragua ', 'DALASI | Gambia ', 'DENAR | Macedonia (Former Yug. Rep.) ', 'DINAR | Algeria ', 'DIRHAM  | Morocco ', 'DOBRA | São Tom and Príncipe ', 'DONG | Vietnam ', 'DRAM | Armenia ', 'ESCUDO  | Cape Verde ', 'EURO  | Belgium ', 'FLORIN | Aruba ', 'FORINT | Hungary ', 'GOURDE | Haiti ', 'GUARANI | Paraguay ', 'GULDEN | Netherlands Antilles ', 'HRYVNIA  | Ukraine ', 'KINA | Papua New Guinea ', 'KIP | Laos ', 'KONVERTIBILNA MARKA  | Bosnia-Herzegovina ', 'KORUNA  | Czech Republic ', 'KRONA | Sweden ', 'KRONE | Denmark ', 'KROON | Estonia ', 'KUNA | Croatia ', 'KWACHA | Zambia ', 'KWANZA | Angola ', 'KYAT | Myanmar ', 'LARI | Georgia ', 'LATS | Latvia ', 'LEK | Albania ', 'LEMPIRA | Honduras ', 'LEONE | Sierra Leone ', 'LEU | Romania ', 'LEV | Bulgaria ', 'LILANGENI  | Swaz
# ...

# %%
    # filtering StopWords_DatesandNumbers Stop words from the text
    with open("stopWords/StopWords_DatesandNumbers.txt") as f:
        StopWords_DatesandNumbers = f.read().splitlines()
        print(StopWords_DatesandNumbers)

    StopWords_DatesandNumbers=[x.lower() for x in StopWords_DatesandNumbers]
    print(StopWords_DatesandNumbers)

    text = StopWord(text,StopWords_DatesandNumbers)
# Out:
# ['HUNDRED  | Denominations', 'THOUSAND', 'MILLION', 'BILLION', 'TRILLION', 'DATE  | Time related', 'ANNUAL', 'ANNUALLY', 'ANNUM', 'YEAR', 'YEARLY', 'QUARTER', 'QUARTERLY', 'QTR', 'MONTH', 'MONTHLY', 'WEEK', 'WEEKLY', 'DAY', 'DAILY', 'JANUARY  | Calendar', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER', 'DECEMBER', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'SEPT', 'OCT', 'NOV', 'DEC', 'MONDAY', 'TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY', 'ONE  | Numbers', 'TWO', 'THREE', 'FOUR', 'FIVE', 'SIX', 'SEVEN', 'EIGHT', 'NINE', 'TEN', 'ELEVEN', 'TWELVE', 'THIRTEEN', 'FOURTEEN', 'FIFTEEN', 'SIXTEEN', 'SEVENTEEN', 'EIGHTEEN', 'NINETEEN', 'TWENTY', 'THIRTY', 'FORTY', 'FIFTY', 'SIXTY', 'SEVENTY', 'EIGHTY', 'NINETY', 'FIRST', 'SECOND', 'THIRD', 'FOURTH', 'FIFTH', 'SIXTH', 'SEVENTH', 'EIGHTH', 'NINTH', 'TENTH', 'I  | Roman numerals', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 'XI', 'XII', 'XI
# ...

# %%
    # filtering StopWords_Generic Stop words from the text
    with open("stopWords/StopWords_Generic.txt") as f:
        StopWords_Generic = f.read().splitlines()
        print(StopWords_Generic)

    StopWords_Generic=[x.lower() for x in StopWords_Generic]
    print(StopWords_Generic)

    text = StopWord(text,StopWords_Generic)
# Out:
# ['ABOUT', 'ABOVE', 'AFTER', 'AGAIN', 'ALL', 'AM', 'AMONG', 'AN', 'AND', 'ANY', 'ARE', 'AS', 'AT', 'BE', 'BECAUSE', 'BEEN', 'BEFORE', 'BEING', 'BELOW', 'BETWEEN', 'BOTH', 'BUT', 'BY', 'CAN', 'DID', 'DO', 'DOES', 'DOING', 'DOWN', 'DURING', 'EACH', 'FEW', 'FOR', 'FROM', 'FURTHER', 'HAD', 'HAS', 'HAVE', 'HAVING', 'HE', 'HER', 'HERE', 'HERS', 'HERSELF', 'HIM', 'HIMSELF', 'HIS', 'HOW', 'IF', 'IN', 'INTO', 'IS', 'IT', 'ITS', 'ITSELF', 'JUST', 'ME', 'MORE', 'MOST', 'MY', 'MYSELF', 'NO', 'NOR', 'NOT', 'NOW', 'OF', 'OFF', 'ON', 'ONCE', 'ONLY', 'OR', 'OTHER', 'OUR', 'OURS', 'OURSELVES', 'OUT', 'OVER', 'OWN', 'SAME', 'SHE', 'SHOULD', 'SO', 'SOME', 'SUCH', 'THAN', 'THAT', 'THE', 'THEIR', 'THEIRS', 'THEM', 'THEMSELVES', 'THEN', 'THERE', 'THESE', 'THEY', 'THIS', 'THOSE', 'THROUGH', 'TO', 'TOO', 'UNDER', 'UNTIL', 'UP', 'VERY', 'WAS', 'WE', 'WERE', 'WHAT', 'WHEN', 'WHERE', 'WHICH', 'WHILE', 'WHO', 'WHOM', 'WHY', 'WITH', 'YOU', 'YOUR', 'YOURS', 'YOURSELF', 'YOURSELVES']
# ...

# %%
    # filteringStopWords_GenericLong Stop words from the text
    with open("stopWords/StopWords_GenericLong.txt") as f:
        StopWords_GenericLong = f.read().splitlines()
        print(StopWords_GenericLong)

    StopWords_GenericLong=[x.lower() for x in StopWords_GenericLong]
    print(StopWords_GenericLong)

    text1= StopWord(text,StopWords_GenericLong)
# Out:
# ['a', "a's", 'able', 'about', 'above', 'according', 'accordingly', 'across', 'actually', 'after', 'afterwards', 'again', 'against', "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear', 'appreciate', 'appropriate', 'are', "aren't", 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away', 'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'best', 'better', 'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon", "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause', 'causes', 'certain', 'certainly', 'changes', 'clearly', 'co', 'com', 'come', 'comes', 'concerning', 'consequently', 'consider', 'considering', 'contain', 'containing', 'con
# ...

# %%
    # filtering StopWords_Geographic Stop words from the text
    with open("stopWords/StopWords_Geographic.txt") as f:
        StopWords_Geographic = f.read().splitlines()
        print(StopWords_Geographic)

    StopWords_Geographic=[x.lower() for x in StopWords_Geographic]
    print(StopWords_Geographic)

    text = StopWord(text1,StopWords_Geographic)
# Out:
# ['UNITED  | Geographic', 'STATE', 'NORTH', 'SOUTH', 'EAST', 'NORTHEAST', 'NORTHWEST', 'SOUTHEAST', 'SOUTHWEST', 'WEST', 'OCEAN', 'SEA', 'LAKE', 'RIVER', 'CREEK', 'GULF', 'MOUNTAIN', 'STREET', 'BOULEVARD', 'BLVD', 'PARKWAY', 'CITY', 'COUNTY', 'COUNTRY', 'PACIFIC', 'ATLANTIC', 'INDIAN', 'MEDITERRANEAN', 'COMMONWEALTH', 'AMERICA', 'AMERICAN', 'YORK  | Cities', 'CHICAGO', 'LAS', 'VEGAS', 'LOS', 'ANGELES', 'MILWAUKEE', 'SUNNYVALE', 'FREMONT', 'CINCINNATI', 'PHILADELPHIA', 'MIAMI', 'DALLAS', 'FORT', 'BOSTON', 'HOUSTON', 'WASHINGTON', 'ATLANTA', 'DETROIT', 'SAN', 'FRANSICO', 'PHOENIX', 'SEATTLE', 'DIEGO', 'MINNEAPOLIS', 'MEMPHIS', 'DENVER', 'ST', 'LOUIS', 'PITTSBURGH', 'MANHATTAN', 'HOLLYWOOD', 'COLUMBUS', 'INDIANAPOLIS', 'MUMBAI', 'KARACHI', 'ONTARIO', 'TORONTO', 'CAMBRIDGE', 'DELHI', 'SAO', 'PAULO', 'SHANGHAI', 'MOSCOW', 'SEOUL', 'ISTANBUL', 'TOKYO', 'JAKARTA', 'BEIJING', 'LONDON', 'LUXEMBOURG', 'SINGAPORE', 'REPUBLIC  | Countries', 'CHINA', 'INDIA', 'INDONESIA', 'BRAZIL', 'BRAZILIAN', 'P
# ...

# %%
    # filtering StopWords_Names Stop words from the text
    with open("stopWords/StopWords_Names.txt") as f:
        StopWords_Names = f.read().splitlines()
        print(StopWords_Names)

    StopWords_Names=[x.lower() for x in StopWords_Names]
    print(StopWords_Names)

    text = StopWord(text,StopWords_Names)
# Out:
# ['SMITH  | Surnames from 1990 census > .002%.  www.census.gov.genealogy/names/dist.all.last', 'JOHNSON', 'WILLIAMS', 'JONES', 'BROWN', 'DAVIS', 'MILLER', 'WILSON', 'MOORE', 'TAYLOR', 'ANDERSON', 'THOMAS', 'JACKSON', 'WHITE', 'HARRIS', 'MARTIN', 'THOMPSON', 'GARCIA', 'MARTINEZ', 'ROBINSON', 'CLARK', 'RODRIGUEZ', 'LEWIS', 'LEE', 'WALKER', 'HALL', 'ALLEN', 'YOUNG', 'HERNANDEZ', 'KING', 'WRIGHT', 'LOPEZ', 'HILL', 'SCOTT', 'GREEN', 'ADAMS', 'BAKER', 'GONZALEZ', 'NELSON', 'CARTER', 'MITCHELL', 'PEREZ', 'ROBERTS', 'TURNER', 'PHILLIPS', 'CAMPBELL', 'PARKER', 'EVANS', 'EDWARDS', 'COLLINS', 'STEWART', 'SANCHEZ', 'MORRIS', 'ROGERS', 'REED', 'COOK', 'MORGAN', 'BELL', 'MURPHY', 'BAILEY', 'RIVERA', 'COOPER', 'RICHARDSON', 'COX', 'HOWARD', 'WARD', 'TORRES', 'PETERSON', 'GRAY', 'RAMIREZ', 'JAMES', 'WATSON', 'BROOKS', 'KELLY', 'SANDERS', 'PRICE', 'BENNETT', 'WOOD', 'BARNES', 'ROSS', 'HENDERSON', 'COLEMAN', 'JENKINS', 'PERRY', 'POWELL', 'LONG', 'PATTERSON', 'HUGHES', 'FLORES', 'WASHINGTON', 'BUTLER', 
# ...

# %%
    doc = nlp(text)
    token_list = [token for token in doc]
    len(token_list)
# Out:
# 531

# %%
    #break sentence
    def break_sentences(text):
        nlp = spacy.load('en_core_web_sm')
        doc = nlp(text)
        return list(doc.sents)


    #no of word function
    def word_count(text):
        sentences = break_sentences(text)
        words = 0
        for sentence in sentences:
            words += len([token for token in sentence])
        return words


    #no of sentence function
    def sentence_count(text):
        sentences = break_sentences(text)
        return len(sentences)

# %% [markdown]
# # Positive Score

# %%
    with open("MasterD/positive-words.txt") as p:
        Positive_words = p.read().splitlines()
    tokens =text.split(" ")
    Positive_words=[x.lower() for x in Positive_words]
    pcount=0
    for word in tokens: 
        if word.lower() in Positive_words:
            pcount=pcount+1;
    Postive_Score.append(pcount)

# %% [markdown]
# # Negative Score

# %%
    with open("MasterD/negative-words.txt") as p:
        Positive_words = p.read().splitlines()
    tokens =text.split(" ")
    Positive_words=[x.lower() for x in Positive_words]
    ncount=0
    for word in tokens: 
        if word.lower() in Positive_words:
            ncount=ncount+1;
    Negative_Score.append(ncount)

# %% [markdown]
# # Polarity Score

# %%
    Polarity_Score.append((Postive_Score[i] - Negative_Score[i])/ ((Postive_Score[i]+Negative_Score[i]) + 0.000001))
    print(Polarity_Score)
# Out:
# 113
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/1259436116.py in <module>
#       1 print(i)
# ----> 2 Polarity_Score.append((Postive_Score[i] - Negative_Score[i])/ ((Postive_Score[i]+Negative_Score[i]) + 0.000001))
#       3 print(Polarity_Score)
#
# IndexError: list index out of range

# %% [markdown]
# # Subjective score

# %%
    Subjectivity_Score.append((Postive_Score[i] +Negative_Score[i])/ ((len(token_list)) + 0.000001))
    print(Subjectivity_Score)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/1089119566.py in <module>
# ----> 1 Subjectivity_Score.append((Postive_Score[i] +Negative_Score[i])/ ((len(token_list)) + 0.000001))
#       2 print(Subjectivity_Score)
#
# IndexError: list index out of range

# %% [markdown]
# # Average Word Length

# %%
    AVG_SENTENCE_LENGTH.append(word_count(text)/ sentence_count(text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/4011345789.py in <module>
# ----> 1 AVG_SENTENCE_LENGTH.append(word_count(text)/ sentence_count(text))
#
# NameError: name 'word_count' is not defined

# %% [markdown]
# # Percentage of Complex words

# %%
import spacy
from textstat.textstat import textstatistics
    def complex_words(text):

        nlp = spacy.load('en_core_web_sm')
        doc = nlp(text)
        # Find all words in the text
        words = []
        sentences = break_sentences(text)
        for sentence in sentences:
            words += [str(token) for token in sentence]

        # complex words are those with syllables > 2
        # easy_word_set is provide by Textstat as
        # a list of common words
        diff_words_set = set()

        for word in words:
            syllable_count =textstatistics().syllable_count(word)
            if word not in nlp.Defaults.stop_words and syllable_count > 2:
                diff_words_set.add(word)

        return len(diff_words_set)
# Out:
#   File "C:\Users\gargi\AppData\Local\Temp/ipykernel_23332/130354829.py", line 3
#     def complex_words(text):
#     ^
# IndentationError: unexpected indent

# %%
    PERCENTAGE_COMPLEX_WORDS.append(complex_words(text)/word_count(text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/573305205.py in <module>
# ----> 1 PERCENTAGE_COMPLEX_WORDS.append(complex_words(text)/word_count(text))
#
# NameError: name 'complex_words' is not defined

# %% [markdown]
# # Fog Index

# %%
    # Returns average sentence length
    def avg_sentence_length(text):
        words = word_count(text)
        sentences = sentence_count(text)
        average_sentence_length = float(words / sentences)
        return average_sentence_length

# %%
    FOG_INDEX.append(0.4 * (avg_sentence_length(text)+PERCENTAGE_COMPLEX_WORDS[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/1760237698.py in <module>
# ----> 1 FOG_INDEX.append(0.4 * (avg_sentence_length(text)+PERCENTAGE_COMPLEX_WORDS[i]))
#
# NameError: name 'text' is not defined

# %% [markdown]
# # Average Number of Words Per Sentence

# %%
    AVG_NUMBER_OF_WORDS_PER_SENTENCE.append(word_count(text)/ sentence_count(text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/1390496689.py in <module>
# ----> 1 AVG_NUMBER_OF_WORDS_PER_SENTENCE.append(word_count(text)/ sentence_count(text))
#
# NameError: name 'word_count' is not defined

# %% [markdown]
# # Complex Word Count

# %%
    COMPLEX_WORD_COUNT.append(complex_words(text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/2119466454.py in <module>
# ----> 1 COMPLEX_WORD_COUNT.append(complex_words(text))
#
# NameError: name 'complex_words' is not defined

# %% [markdown]
# # Word Count

# %%
    WORD_COUNT.append(len(text))
    print(len(text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23332/1640328065.py in <module>
# ----> 1 WORD_COUNT.append(len(text))
#       2 print(len(text))
#
# NameError: name 'text' is not defined

# %% [markdown]
# # Syllable Count Per Word

# %%
    def avg_syllables_per_word(text):
        text= [re.sub('(es|ed)$', '', w) for w in text]
        syllable = syllables_count(text)
        words = word_count(text)
        ASPW = float(syllable) / float(words)
        return legacy_round(ASPW, 1)
    print(len(text))

# %%
    SYLLABLE_PER_WORD.append(avg_syllables_per_word)

# %% [markdown]
# # Personal Pronouns

# %%
    #“I,” “we,” “my,” “ours,” and “us”
    pronounRegex = re.compile(r'\b(I|we|my|ours|(?-i:us))\b',re.I)
    pronouns = pronounRegex.findall(text)
    print(len(pronouns))
    PERSONAL_PRONOUNS.append(len(pronouns))

# %% [markdown]
# # Average Word Length

# %%
    def Average_word_length(text):
        words = text.split()
        average = sum(len(word) for word in words) / len(words)
        return average
    AVG_WORD_LENGTH.append(Average_word_length(text))

# %%
    print(len(token_list))
    print(len(text))

# %%
df["Positive Score"]= Postive_Score
df["Negative Score"]= Negative_Score
df["Polarity Score"]=Polarity_Score
df["Subjectivity Score"]=Subjectivity_Score
df["Average Word Length"]= AVG_SENTENCE_LENGTH
df["PERCENTAGE COMPLEX WORDS"]= PERCENTAGE_COMPLEX_WORDS
df["FOG_INDEX"]=FOG_INDEX
df["AVG_NUMBER_OF_WORDS_PER_SENTENCE"]=AVG_NUMBER_OF_WORDS_PER_SENTENCE
df["COMPLEX_WORD_COUNT"]=COMPLEX_WORD_COUNT
df["WORD_COUNT"]=  WORD_COUNT
df["SYLLABLE_PER_WORD"]=SYLLABLE_PER_WORD
df["PERSONAL_PRONOUNS"]=PERSONAL_PRONOUNS
df["AVG_WORD_LENGTH"]=AVG_WORD_LENGTH

# %%
df
